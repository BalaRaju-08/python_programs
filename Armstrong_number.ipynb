# %%
# Armstrong number using while loop 
a=int(input("enter the number:"))
sum=0
power=len(str(a))
i=a

while i>0:
    digit=i%10 # is exract the last number you enter the 153 the this line give the numbers one by one 3,5,1
    sum=sum+digit**power# this line calucate the sum
    i=i//10 # remove the last digit from the given number 
print(sum)
if sum==a:
    print("it is a Armstrong number")
else:
    print("it is not Armstrong number")
# Out:
# 153
# it is a Armstrong number

# %%
# Armstrong number using the for loop 
a=int(input("enter the number:"))
power=len(str(a))
sum=0
b=str(a)
for i in (b):
    digit=int(i)
    sum=sum+digit**power
print(sum)
if sum==a:
    print("it is a Armstrong number")
else:
    print("it is not Armstrong number")
# Out:
# 153
# it is a Armstrong number
